# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
delta_X = np.random.normal(0,1,(2,5))

# %%
delta_X
# Out:
# array([[ 0.82066847,  2.37385008, -0.80347456,  0.98175862, -0.79866496],
#        [ 0.72613827,  0.61912705, -2.36015237, -0.01089937,  1.06789603]])

# %%
plt.plot(delta_X[0],delta_X[1], 'go')
plt.show()

# %%
X = np.cumsum(delta_X, axis = 1) #columns

# %%
X
# Out:
# array([[-0.23119879,  0.43443575, -0.14732008, -1.87965437, -1.56294562],
#        [ 0.16458308,  0.73111823,  0.72970373, -0.04779704,  0.62532163]])

# %%
delta_X
# Out:
# array([[ -2.31198790e-01,   6.65634544e-01,  -5.81755836e-01,
#          -1.73233429e+00,   3.16708752e-01],
#        [  1.64583080e-01,   5.66535152e-01,  -1.41449868e-03,
#          -7.77500777e-01,   6.73118678e-01]])

# %%
delta_X = np.random.normal(0,1,(2,5))
X = np.cumsum(delta_X, axis = 1)
plt.plot(X[0], X[1])
plt.show()

# %%
delta_X = np.random.normal(0,1,(2,5))
X = np.cumsum(delta_X, axis = 1)
plt.plot(X[0], X[1], 'ro-')
plt.savefig('rw.pdf')
plt.show()

# %%
X_0 = np.array([[0],[0]])

# %%
X_0
# Out:
# array([[0],
#        [0]])

# %%
#X = np.concatenate((X_0, delta_X), axis = 1)
X = np.concatenate((X_0, np.cumsum(delta_X, axis = 1)), axis = 1)

# %%
X
# Out:
# array([[ 0.        ,  0.82066847,  3.19451855,  2.39104399,  3.37280261,
#          2.57413765],
#        [ 0.        ,  0.72613827,  1.34526532, -1.01488705, -1.02578642,
#          0.04210961]])

# %%
delta_X
# Out:
# array([[ 0.82066847,  2.37385008, -0.80347456,  0.98175862, -0.79866496],
#        [ 0.72613827,  0.61912705, -2.36015237, -0.01089937,  1.06789603]])

# %%
delta_X = np.random.normal(0,1,(2,5))
X_0 = np.array([[0],[0]])
X = np.concatenate((X_0, np.cumsum(delta_X, axis = 1)), axis = 1)
plt.plot(X[0], X[1], 'ro-')
plt.savefig('rw2.pdf')
plt.show()

# %%
delta_X = np.random.normal(0,1,(2,100))
X_0 = np.array([[0],[0]])
X = np.concatenate((X_0, np.cumsum(delta_X, axis = 1)), axis = 1)
plt.plot(X[0], X[1], 'ro-')
plt.savefig('rw3.pdf')
plt.show()

# %%
delta_X = np.random.normal(0,1,(2,10000))
X_0 = np.array([[0],[0]])
X = np.concatenate((X_0, np.cumsum(delta_X, axis = 1)), axis = 1)
plt.plot(X[0], X[1], 'ro-')
plt.savefig('rw4.pdf')
plt.show()
